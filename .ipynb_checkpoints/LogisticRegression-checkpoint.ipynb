# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# TODO - Application 3 - Step 5 - Create the ANN model
def modelDefinition():

    # TODO - Application 3 - Step 5a - Define the model as a Sequential model
    model = Sequential()

    # TODO - Application 3 - Step 5b - Add a Dense layer with 8 neurons to the model
    model.add(Dense(8, input_dim=13, kernel_initializer='normal', activation='relu'))
    
    # TODO - Application 3 - Step 5c - Add a Dense layer (output layer) with 1 neuron
    model.add(Dense(1, kernel_initializer='normal'))

    # TODO - Application 3 - Step 5d - Compile the model by choosing the optimizer(adam) ant the loss function (MSE)
    model.compile(loss="mean_squared_error", optimizer="adam")
    return model

# %%
def main():

    # TODO - Application 3 - Step 1 - Read data from "Houses.csv" file
    data = pd.read_csv("./Houses.csv").values

    # TODO - Application 3 - Step 2 - Shuffle the data
    np.random.shuffle(data)
    
    # TODO - Application 3 - Step 3 - Separate the data from the labels (x_data / y_data)
    x_data = data[:, :-1]
    y_data = data[:,-1]

    # TODO - Application 3 - Step 4 - Separate the data into training/testing dataset
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)
    # random_state=42: A seed for the random number generator used to shuffle the dataset before splitting. Setting a specific random_state ensures reproducibility of the results, as the split will be the same every time the script is run.

    # TODO - Application 3 - Step 5 - Call the function "modelDefinition"
    model = modelDefinition()

    # TODO - Application 3 - Step 6 - Train the model for 100 epochs and a batch of 16 samples
    model.fit(x_train, y_train, epochs=100, batch_size=16, verbose=2)

    # TODO - Application 3 - Step 7 - Predict the house price for all the samples in the testing dataset
    predictions = model.predict(x_test)

    # TODO - Exercise 8 - Compute the MSE for the test data
    mse = np.mean((predictions.flatten() - y_test)**2) #.flatten() method is used to convert it into a 1D array for straightforward operations.

    print("Mean Square Error = {}".format(mse))

# %%
if __name__ == '__main__':
    main()
# Out:
# Epoch 1/100
# 26/26 - 0s - loss: 591.8625 - 145ms/epoch - 6ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 514.1324 - 12ms/epoch - 454us/step
# Epoch 3/100
# 26/26 - 0s - loss: 367.4643 - 12ms/epoch - 448us/step
# Epoch 4/100
# 26/26 - 0s - loss: 215.6956 - 11ms/epoch - 433us/step
# Epoch 5/100
# 26/26 - 0s - loss: 138.6179 - 11ms/epoch - 420us/step
# Epoch 6/100
# 26/26 - 0s - loss: 120.9263 - 11ms/epoch - 433us/step
# Epoch 7/100
# 26/26 - 0s - loss: 116.2882 - 12ms/epoch - 449us/step
# Epoch 8/100
# 26/26 - 0s - loss: 111.4933 - 11ms/epoch - 411us/step
# Epoch 9/100
# 26/26 - 0s - loss: 107.5148 - 11ms/epoch - 416us/step
# Epoch 10/100
# 26/26 - 0s - loss: 103.2092 - 11ms/epoch - 423us/step
# Epoch 11/100
# 26/26 - 0s - loss: 99.4695 - 11ms/epoch - 423us/step
# Epoch 12/100
# 26/26 - 0s - loss: 95.8574 - 11ms/epoch - 413us/step
# Epoch 13/100
# 26/26 - 0s - loss: 92.6394 - 11ms/epoch - 438us/step
# Epoch 14/100
# 26/26 - 0s - loss: 89.9838 - 11ms/epoch - 421us/step
# Epoch 15/100
# 26/26 - 0s - loss: 87.3100 - 11ms/epoch - 424us/step
# Epoch 16/100
# 26/26 - 0s - loss: 85.2102 - 11ms/epoch - 428us/step
# Epoch 17/100
# 26/26 - 0s - loss: 83.0308 - 11ms/epoch - 421us/step
# Epoch 18/100
# 26/26 - 0s - loss: 81.4871 - 11ms/epoch - 423us/step
# Epoch 19/100
# 26/26 - 0s - loss: 80.0625 - 11ms/epoch - 410us/step
# Epoch 20/100
# 26/26 - 0s - loss: 78.8157 - 11ms/epoch - 416us/step
# Epoch 21/100
# 26/26 - 0s - loss: 77.7292 - 11ms/epoch - 406us/step
# Epoch 22/100
# 26/26 - 0s - loss: 76.9445 - 11ms/epoch - 406us/step
# Epoch 23/100
# 26/26 - 0s - loss: 76.1580 - 11ms/epoch - 426us/step
# Epoch 24/100
# 26/26 - 0s - loss: 76.4633 - 11ms/epoch - 416us/step
# Epoch 25/100
# 26/26 - 0s - loss: 75.4173 - 11ms/epoch - 409us/step
# Epoch 26/100
# 26/26 - 0s - loss: 74.7362 - 10ms/epoch - 400us/step
# Epoch 27/100
# 26/26 - 0s - loss: 74.4499 - 11ms/epoch - 418us/step
# Epoch 28/100
# 26/26 - 0s - loss: 74.2772 - 11ms/epoch - 408us/step
# Epoch 29/100
# 26/26 - 0s - loss: 73.6547 - 11ms/epoch - 412us/step
# Epoch 30/100
# 26/26 - 0s - loss: 73.4912 - 11ms/epoch - 412us/step
# Epoch 31/100
# 26/26 - 0s - loss: 73.0215 - 11ms/epoch - 412us/step
# Epoch 32/100
# 26/26 - 0s - loss: 72.8851 - 11ms/epoch - 423us/step
# Epoch 33/100
# 26/26 - 0s - loss: 72.6154 - 11ms/epoch - 430us/step
# Epoch 34/100
# 26/26 - 0s - loss: 72.3554 - 11ms/epoch - 429us/step
# Epoch 35/100
# 26/26 - 0s - loss: 72.0294 - 11ms/epoch - 417us/step
# Epoch 36/100
# 26/26 - 0s - loss: 72.1429 - 10ms/epoch - 398us/step
# Epoch 37/100
# 26/26 - 0s - loss: 71.8176 - 10ms/epoch - 394us/step
# Epoch 38/100
# 26/26 - 0s - loss: 71.3970 - 11ms/epoch - 419us/step
# Epoch 39/100
# 26/26 - 0s - loss: 71.5407 - 12ms/epoch - 453us/step
# Epoch 40/100
# 26/26 - 0s - loss: 71.1126 - 12ms/epoch - 457us/step
# Epoch 41/100
# 26/26 - 0s - loss: 71.0867 - 12ms/epoch - 443us/step
# Epoch 42/100
# 26/26 - 0s - loss: 70.5552 - 12ms/epoch - 445us/step
# Epoch 43/100
# 26/26 - 0s - loss: 70.4108 - 13ms/epoch - 512us/step
# Epoch 44/100
# 26/26 - 0s - loss: 70.1033 - 14ms/epoch - 537us/step
# Epoch 45/100
# 26/26 - 0s - loss: 69.9382 - 13ms/epoch - 518us/step
# Epoch 46/100
# 26/26 - 0s - loss: 69.6284 - 13ms/epoch - 501us/step
# Epoch 47/100
# 26/26 - 0s - loss: 69.6613 - 11ms/epoch - 439us/step
# Epoch 48/100
# 26/26 - 0s - loss: 69.1882 - 13ms/epoch - 505us/step
# Epoch 49/100
# 26/26 - 0s - loss: 68.8784 - 14ms/epoch - 554us/step
# Epoch 50/100
# 26/26 - 0s - loss: 68.7836 - 14ms/epoch - 536us/step
# Epoch 51/100
# 26/26 - 0s - loss: 68.3537 - 14ms/epoch - 529us/step
# Epoch 52/100
# 26/26 - 0s - loss: 68.1400 - 14ms/epoch - 532us/step
# Epoch 53/100
# 26/26 - 0s - loss: 67.8992 - 13ms/epoch - 500us/step
# Epoch 54/100
# 26/26 - 0s - loss: 67.5956 - 13ms/epoch - 490us/step
# Epoch 55/100
# 26/26 - 0s - loss: 68.4755 - 12ms/epoch - 462us/step
# Epoch 56/100
# 26/26 - 0s - loss: 67.5664 - 12ms/epoch - 478us/step
# Epoch 57/100
# 26/26 - 0s - loss: 66.8015 - 12ms/epoch - 443us/step
# Epoch 58/100
# 26/26 - 0s - loss: 67.0563 - 11ms/epoch - 408us/step
# Epoch 59/100
# 26/26 - 0s - loss: 66.3025 - 11ms/epoch - 427us/step
# Epoch 60/100
# 26/26 - 0s - loss: 66.2532 - 11ms/epoch - 427us/step
# Epoch 61/100
# 26/26 - 0s - loss: 65.9540 - 11ms/epoch - 424us/step
# Epoch 62/100
# 26/26 - 0s - loss: 65.7831 - 46ms/epoch - 2ms/step
# Epoch 63/100
# 26/26 - 0s - loss: 66.4589 - 13ms/epoch - 507us/step
# Epoch 64/100
# 26/26 - 0s - loss: 65.2464 - 14ms/epoch - 535us/step
# Epoch 65/100
# 26/26 - 0s - loss: 64.9859 - 14ms/epoch - 523us/step
# Epoch 66/100
# 26/26 - 0s - loss: 65.0513 - 14ms/epoch - 520us/step
# Epoch 67/100
# 26/26 - 0s - loss: 64.8821 - 13ms/epoch - 517us/step
# Epoch 68/100
# 26/26 - 0s - loss: 64.0492 - 13ms/epoch - 496us/step
# Epoch 69/100
# 26/26 - 0s - loss: 64.0628 - 13ms/epoch - 489us/step
# Epoch 70/100
# 26/26 - 0s - loss: 63.5965 - 14ms/epoch - 530us/step
# Epoch 71/100
# 26/26 - 0s - loss: 63.2497 - 14ms/epoch - 523us/step
# Epoch 72/100
# 26/26 - 0s - loss: 63.0843 - 13ms/epoch - 500us/step
# Epoch 73/100
# 26/26 - 0s - loss: 62.8169 - 13ms/epoch - 498us/step
# Epoch 74/100
# 26/26 - 0s - loss: 62.4446 - 11ms/epoch - 420us/step
# Epoch 75/100
# 26/26 - 0s - loss: 62.1047 - 12ms/epoch - 450us/step
# Epoch 76/100
# 26/26 - 0s - loss: 62.0327 - 11ms/epoch - 437us/step
# Epoch 77/100
# 26/26 - 0s - loss: 61.9131 - 11ms/epoch - 440us/step
# Epoch 78/100
# 26/26 - 0s - loss: 61.4138 - 11ms/epoch - 406us/step
# Epoch 79/100
# 26/26 - 0s - loss: 61.3575 - 12ms/epoch - 445us/step
# Epoch 80/100
# 26/26 - 0s - loss: 60.9214 - 11ms/epoch - 439us/step
# Epoch 81/100
# 26/26 - 0s - loss: 60.5628 - 11ms/epoch - 424us/step
# Epoch 82/100
# 26/26 - 0s - loss: 60.3546 - 11ms/epoch - 431us/step
# Epoch 83/100
# 26/26 - 0s - loss: 60.7859 - 11ms/epoch - 439us/step
# Epoch 84/100
# 26/26 - 0s - loss: 60.2428 - 12ms/epoch - 444us/step
# Epoch 85/100
# 26/26 - 0s - loss: 59.6307 - 11ms/epoch - 418us/step
# Epoch 86/100
# 26/26 - 0s - loss: 59.2349 - 11ms/epoch - 438us/step
# Epoch 87/100
# 26/26 - 0s - loss: 58.9688 - 11ms/epoch - 440us/step
# Epoch 88/100
# 26/26 - 0s - loss: 58.5771 - 11ms/epoch - 434us/step
# Epoch 89/100
# 26/26 - 0s - loss: 58.3709 - 11ms/epoch - 421us/step
# Epoch 90/100
# 26/26 - 0s - loss: 58.1717 - 12ms/epoch - 448us/step
# Epoch 91/100
# 26/26 - 0s - loss: 57.9915 - 11ms/epoch - 441us/step
# Epoch 92/100
# 26/26 - 0s - loss: 57.7943 - 11ms/epoch - 412us/step
# Epoch 93/100
# 26/26 - 0s - loss: 57.5123 - 12ms/epoch - 450us/step
# Epoch 94/100
# 26/26 - 0s - loss: 57.0131 - 11ms/epoch - 440us/step
# Epoch 95/100
# 26/26 - 0s - loss: 56.7885 - 11ms/epoch - 431us/step
# Epoch 96/100
# 26/26 - 0s - loss: 56.8821 - 11ms/epoch - 419us/step
# Epoch 97/100
# 26/26 - 0s - loss: 56.2810 - 12ms/epoch - 451us/step
# Epoch 98/100
# 26/26 - 0s - loss: 56.0387 - 12ms/epoch - 453us/step
# Epoch 99/100
# 26/26 - 0s - loss: 55.6670 - 11ms/epoch - 425us/step
# Epoch 100/100
# 26/26 - 0s - loss: 55.7707 - 11ms/epoch - 430us/step
# 4/4 [==============================] - 0s 716us/step
# Mean Square Error = 46.34095631306787
