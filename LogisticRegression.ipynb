# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
def modelDefinition(input_shape):
    model = Sequential()
    
    model.add(Dense(8, input_dim=input_shape, kernel_initializer='normal', activation='relu'))  # First hidden layer with 8 neurons
    model.add(Dense(16, activation='relu'))  # Second hidden layer with 16 neurons
    model.add(Dense(1, kernel_initializer='normal', activation='linear'))  # linear activation for regression

    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
def main():

    # TODO - Application 3 - Step 1 - Read data from "Houses.csv" file
    data = pd.read_csv("./Houses.csv").sample(frac=1).reset_index(drop=True)
    
    # TODO - Application 3 - Step 3 - Separate the data from the labels (x_data / y_data)
    x_data = data.drop('noxious',axis=1).values
    y_data = data['noxious'].values

    # TODO - Application 3 - Step 4 - Separate the data into training/testing dataset
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)
    # random_state=42: A seed for the random number generator used to shuffle the dataset before splitting. Setting a specific random_state ensures reproducibility of the results, as the split will be the same every time the script is run.

    # TODO - Application 3 - Step 5 - Call the function "modelDefinition"
    model = modelDefinition(x_train.shape[1])

    # TODO - Application 3 - Step 6 - Train the model for 100 epochs and a batch of 16 samples
    model.fit(x_train, y_train, epochs=100, batch_size=16, verbose=2)

    # TODO - Application 3 - Step 7 - Predict the house price for all the samples in the testing dataset
    predictions = model.predict(x_test)

    # TODO - Exercise 8 - Compute the MSE for the test data
    mse = np.mean((predictions.flatten() - y_test)**2) #.flatten() method is used to convert it into a 1D array for straightforward operations.

    print("Mean Square Error = {:.2f}".format(mse))

# %%
if __name__ == '__main__':
    main()
# Out:
# Epoch 1/100
# 26/26 - 0s - loss: 0.0202 - 208ms/epoch - 8ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 0.0091 - 13ms/epoch - 502us/step
# Epoch 3/100
# 26/26 - 0s - loss: 0.0070 - 13ms/epoch - 515us/step
# Epoch 4/100
# 26/26 - 0s - loss: 0.0067 - 12ms/epoch - 480us/step
# Epoch 5/100
# 26/26 - 0s - loss: 0.0066 - 12ms/epoch - 468us/step
# Epoch 6/100
# 26/26 - 0s - loss: 0.0059 - 13ms/epoch - 508us/step
# Epoch 7/100
# 26/26 - 0s - loss: 0.0057 - 11ms/epoch - 442us/step
# Epoch 8/100
# 26/26 - 0s - loss: 0.0063 - 12ms/epoch - 463us/step
# Epoch 9/100
# 26/26 - 0s - loss: 0.0054 - 12ms/epoch - 459us/step
# Epoch 10/100
# 26/26 - 0s - loss: 0.0051 - 12ms/epoch - 453us/step
# Epoch 11/100
# 26/26 - 0s - loss: 0.0048 - 11ms/epoch - 435us/step
# Epoch 12/100
# 26/26 - 0s - loss: 0.0054 - 12ms/epoch - 464us/step
# Epoch 13/100
# 26/26 - 0s - loss: 0.0052 - 12ms/epoch - 466us/step
# Epoch 14/100
# 26/26 - 0s - loss: 0.0054 - 12ms/epoch - 454us/step
# Epoch 15/100
# ...
